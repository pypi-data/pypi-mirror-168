# %%
import pandas as pd

# %%
import sys
PACKAGE_FOLDER = "/Users/danielfiuzadosil/Documents/GitHub/raptor_functions/raptor_functions"
PACKAGE_FOLDER = "/Users/amash/Insync/GDrive/Projects/Raptor/raptor_functions"
sys.path.insert(0, PACKAGE_FOLDER)

# %%
path_to_measurements = 'data'

# %%
from raptor_functions.supervised.preprocess import preprocess_all_files
df = preprocess_all_files(path_to_measurements, has_label= False)

# %%
df.to_csv('data/data.csv')

# %%
df.columns
# Out:
# Index(['timesteps', 'sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5',
#        'sensor_6', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10',
#        'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15',
#        'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
#        'sensor_21', 'sensor_22', 'sensor_23', 'sensor_24', ' Humidity (r.h.)',
#        'exp_unique_id', 'measurement_stage', 'date_exp', 'time_elapsed',
#        'datetime_exp_start', 'filename', 'exp_name', 'repeat_no'],
#       dtype='object')

# %%
df = pd.read_csv('/Users/amash/Insync/GDrive/Projects/Raptor/raptor_functions/raptor_functions/examples/daniel_examples/pigs_data/data.csv', index_col=0)

# %%
df
# Out:
#      timesteps  sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  sensor_6  \
# 0            1   476.250   397.227   492.131   479.955   497.618   195.377
# 1            2   474.049   395.030   491.355   477.726   496.040   194.976
# 2            3   474.781   395.030   491.355   476.987   496.040   194.976
# 3            4   474.781   395.030   492.131   477.726   496.828   194.776
# 4            5   475.514   393.939   492.909   476.250   496.828   194.776
# ..         ...       ...       ...       ...       ...       ...       ...
# 179        180   473.319   401.678   492.131   473.319   496.040   198.824
# 180        181   471.864   400.558   491.355   474.049   496.828   198.414
# 181        182   472.591   400.558   492.131   474.781   497.618   198.414
# 182        183   473.319   401.678   492.131   473.319   496.040   198.414
# 183        184   473.319   401.117   491.355   474.781   496.040   198.414
#
# ...

# %%
FEATURES = ['sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5',
       'sensor_6', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10',
       'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15',
       'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
       'sensor_21', 'sensor_22', 'sensor_23', 'sensor_24']

# %%
results = ['pig','pig',
'non-pig', 'non-pig',
'pig','pig',
'pig','pig',
'pig','pig',
'pig','pig',
'non-pig','non-pig',
'non-pig','non-pig']

# %%
lst = []
for i, group in enumerate(df.groupby('exp_unique_id')):
    group[1]['result'] = results[i]
    lst.append(group[1])
df = pd.concat(lst)

# %%
df
# Out:
#      timesteps  sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  sensor_6  \
# 0            1   476.250   397.227   492.131   479.955   497.618   195.377
# 1            2   474.049   395.030   491.355   477.726   496.040   194.976
# 2            3   474.781   395.030   491.355   476.987   496.040   194.976
# 3            4   474.781   395.030   492.131   477.726   496.828   194.776
# 4            5   475.514   393.939   492.909   476.250   496.828   194.776
# ..         ...       ...       ...       ...       ...       ...       ...
# 179        180   473.319   401.678   492.131   473.319   496.040   198.824
# 180        181   471.864   400.558   491.355   474.049   496.828   198.414
# 181        182   472.591   400.558   492.131   474.781   497.618   198.414
# 182        183   473.319   401.678   492.131   473.319   496.040   198.414
# 183        184   473.319   401.117   491.355   474.781   496.040   198.414
#
# ...

# %%
from raptor_functions.supervised.feature_extraction import get_training_features
df_f = get_training_features(df,features=FEATURES)

# %%
df_f
# Out:
#     sensor_13__fft_coefficient__attr_"real"__coeff_8  \
# 0                                          -6.547634
# 1                                          -2.503253
# 2                                           9.697768
# 3                                          11.083813
# 4                                           0.052211
# 5                                          -4.504075
# 6                                          -1.255184
# 7                                          -1.518205
# 8                                          -4.241193
# 9                                          11.852708
# 10                                          1.390613
# 11                                          1.165718
# 12                                          8.603381
# 13                                          6.324421
# 14                                          3.099323
#
#     sensor_13__fft_coefficient__attr_"real"__coeff_27  \
# 0                                            8.042483
# ...

# %%
df_f.to_csv('df_f.csv')

# %%
import pandas as pd
import sys
PACKAGE_FOLDER = "/Users/danielfiuzadosil/Documents/GitHub/raptor_functions/raptor_functions"
PACKAGE_FOLDER = "/Users/amash/Insync/GDrive/Projects/Raptor/raptor_functions"
sys.path.insert(0, PACKAGE_FOLDER)

# %%
df_f = pd.read_csv('df_f.csv', index_col=0)
df_f
# Out:
#     sensor_13__fft_coefficient__attr_"real"__coeff_8  \
# 0                                          -6.547634
# 1                                          -2.503253
# 2                                           9.697768
# 3                                          11.083813
# 4                                           0.052211
# 5                                          -4.504075
# 6                                          -1.255184
# 7                                          -1.518205
# 8                                          -4.241193
# 9                                          11.852708
# 10                                          1.390613
# 11                                          1.165718
# 12                                          8.603381
# 13                                          6.324421
# 14                                          3.099323
#
#     sensor_13__fft_coefficient__attr_"real"__coeff_27  \
# 0                                            8.042483
# ...

# %%
import mlflow
from raptor_functions.supervised.train import train_experiments
mlflow.end_run()
train_experiments(df_f, n_trials=5, study_name='pig-exp')
# Out:
# <style type="text/css">
# #T_54e59_row5_col0, #T_54e59_row5_col1, #T_54e59_row5_col2, #T_54e59_row5_col3, #T_54e59_row5_col4, #T_54e59_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_54e59_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Specificity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
# ...
