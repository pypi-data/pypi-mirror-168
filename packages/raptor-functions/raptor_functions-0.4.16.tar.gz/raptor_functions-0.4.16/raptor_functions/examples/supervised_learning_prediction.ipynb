# %% [markdown]
# #### Install raptor-functions

# %%
# !pip install raptor-functions -q

# %% [markdown]
# ### Model Prediction

# %%
from raptor_functions.supervised.prediction import make_ensemble_prediction
from raptor_functions.supervised.preprocess import preprocess_single_file

# %%
f = 'test.txt'

# %%
df_sample = preprocess_single_file(f)
# Out:
# /Users/amash/anaconda3/envs/demodemo/lib/python3.8/site-packages/raptor_functions/supervised/preprocess.py:130: UserWarning: Warning...........Can't get label
#   warnings.warn("Warning...........Can't get label")

# %%
df_sample
# Out:
#      exp_unique_id  timesteps  sensor_1  sensor_2  sensor_3  sensor_4  \
# 0                0        0.0   316.809   315.735   315.687   313.562
# 1                0        1.0   316.427   315.902   316.069   313.729
# 2                0        2.0   316.117   316.403   316.188   313.586
# 3                0        3.0   316.141   315.639   316.093   313.491
# 4                0        4.0   316.857   315.878   315.878   313.419
# ..             ...        ...       ...       ...       ...       ...
# 148              0      148.0   315.806   316.236   316.093   313.753
# 149              0      149.0   316.618   315.806   315.806   313.682
# 150              0      150.0   316.164   315.926   316.069   313.562
# 151              0      151.0   316.499   316.093   315.830   313.324
# 152              0      152.0   316.427   315.878   315.854   313.801
#
#      sensor_5  sensor_6  sensor_7  sensor_8  ...  sensor_24  humidity  \
# ...

# %%
final_pred, preds = make_ensemble_prediction(df_sample)
